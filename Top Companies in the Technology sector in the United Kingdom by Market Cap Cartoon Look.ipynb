# %%
import numpy as np
myrollsA = np.random.choice([3,3,3,3,3,6], size=60000)
myrollsB = np.random.choice([1,4,4,4,4,4], size=60000)
mysum_win  = np.sum(myrollsA > myrollsB)
print(mysum_win)
# Out:
# 18238

# %%
3315*2/3/5*7*11/13
# Out:
# 2618.0

# %%
import matplotlib.pyplot as plt #Top Companies in the Technology sector in the United Kingdom by Market Cap
company = ['Clarivate Plc', 'The Sage Group plc', 'AVEVA Group plc', 'Endava plc', 'Mimecast Limited', 'Atotech Ltd', 'Computacenter plc', 'Softcat plc', 'Darktrace plc', 'Spectris plc']
marketcap = [1754000000, 9830000000, 9600000000, 8100000000, 5120000000, 4480000000, 4440000000, 4310000000, 4130000000, 3910000000]
plt.xkcd()
plt.bar(company,marketcap)
plt.title('Top Companies in the Technology sector in the United Kingdom by Market Cap')
plt.xlabel('company')
plt.ylabel('marketcap')
plt.show()
